# %%
import pandas as pd

# Define the complete historical timeline from 1960 to the current decade
era_data = {
    'Era_ID': [0, 1, 2, 3, 4, 5, 6],
    'Era_Label': ['1960-1969', '1970-1979', '1980-1989', '1990-1999', '2000-2009', '2010-2019', '2020-2029'],
    'League_Avg_PPG': [115.2, 105.5, 108.5, 101.2, 96.5, 103.1, 114.3],
    'League_Avg_Pace': [116.8, 104.2, 100.8, 94.0, 91.2, 96.4, 99.1],
    'League_Avg_TS_Pct': [0.485, 0.508, 0.531, 0.530, 0.542, 0.556, 0.578]
}

# Convert to DataFrame
df_eras = pd.DataFrame(era_data)

# Save it directly over your old baseline file
file_name = 'nba_ml_era_baselines.csv'
df_eras.to_csv(file_name, index=False)

print(f"🎉 SUCCESS: '{file_name}' updated cleanly!")
# Out:
# 🎉 SUCCESS: 'nba_ml_era_baselines.csv' updated cleanly!
